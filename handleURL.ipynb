# %% [markdown]
# # URL Utils
#
# ## URL Recognition
# In original training set
#
# - `"://"` : tweets: 121330, users len: 7340
# - `"http"` : tweets: 121327, users len: 7339
# - `"http://"` : tweets: 121236, users len: 7338
# - `"https://"` : tweets: 47, users len: 35
#
# ## Might related
#
# 1. `:/` as expression in sentence
# ```
#     counter: 276
#     userMap len: 192
#     dict_keys([1, 3, 2, 7, 4, 5])
#     userMap[7] = [5393, 5073]
#     userMap[5] = [7152, 6128]
# ```
# 2. @handle num per twitts

# %% [markdown]
# ## Preprocessing
#
# Remove the `@handle` and `rt`.

# %%
remove_words = ["@handle", "rt"]

def pre_process(sentence):
    sentence = sentence.split()
    target_remove = set()
    for token in sentence:
        for target in remove_words:
            if target in token:
                target_remove.add(token)
                
    for target in target_remove:
        sentence.remove(target)
    
    sentence = ' '.join(sentence)
    return sentence

# %%
import csv
import collections
import time
import matplotlib.pyplot as plt
time_start=time.time()

train_file_path = "data/train_tweets.txt"
train_dict = collections.defaultdict(list)

empty_sentence_counter = 0
with open(train_file_path, encoding='utf-8') as tsvfile:
    for i, row in enumerate(tsvfile.readlines()):
        row = row.strip().split('\t')
        id = int(row[0])
        oldSentence = row[1].lower()
        instance = pre_process(oldSentence)
        if not instance == "":
            train_dict[id].append(instance)
        else:
            print("-----------------------------------")
            print("Empty sentence row:{0}".format(i+1))
            print("id: {0}".format(id))
            print("sentence: {0}".format(oldSentence))
            empty_sentence_counter += 1
    print("Total rows: %d" % i)
print("Total ids: %d" % len(train_dict))

time_end=time.time()
print("Empty sentence counter: {0}".format(empty_sentence_counter))
print("Time spent: {0:.2f}ms".format((time_end-time_start)*1000))
# Out:
# -----------------------------------
# Empty sentence row:4049
# id: 8573
# sentence: @handle
# -----------------------------------
# Empty sentence row:5481
# id: 9151
# sentence: @handle
# -----------------------------------
# Empty sentence row:6224
# id: 1416
# sentence: @handle
# -----------------------------------
# Empty sentence row:6935
# id: 2868
# sentence: @handle
# -----------------------------------
# Empty sentence row:7334
# id: 4330
# sentence: @handle
# -----------------------------------
# Empty sentence row:12343
# id: 130
# sentence: @handle
# -----------------------------------
# Empty sentence row:14434
# id: 4133
# sentence: @handle
# -----------------------------------
# Empty sentence row:14437
# id: 4133
# sentence: @handle
# -----------------------------------
# Empty sentence row:14466
# id: 4133
# sentence: @handle
# -----------------------------------
# Empty sentence row:14803
# id: 446
# sentence: @handle "worthless"
# -----------------------------------
# Empty sentence row:14812
# id: 446
# sentence: @handle
# -----------------------------------
# Empty sentence row:15165
# id: 9740
# sentence: @handle midnights.daydream@handle.com
# -----------------------------------
# Empty sentence row:18745
# id: 458
# sentence: @handle djskoot3@handle
# -----------------------------------
# Empty sentence row:19227
# id: 7225
# sentence: @handle
# -----------------------------------
# Empty sentence row:20198
# id: 3082
# sentence: @handle mjones20754@handle.com
# -----------------------------------
# Empty sentence row:21843
# id: 2906
# sentence: @handle
# -----------------------------------
# Empty sentence row:24921
# id: 9667
# sentence: @handle contact@handle-rich.com
# -----------------------------------
# Empty sentence row:25822
# id: 5713
# sentence: support @handle!
# -----------------------------------
# Empty sentence row:29563
# id: 8864
# sentence: start
# -----------------------------------
# Empty sentence row:34852
# id: 3729
# sentence: @handle
# -----------------------------------
# Empty sentence row:35343
# id: 4539
# sentence: @handle
# -----------------------------------
# Empty sentence row:41522
# id: 6331
# sentence: @handle happybirthdaykaty<333
# -----------------------------------
# Empty sentence row:42053
# id: 4043
# sentence: reports
# -----------------------------------
# Empty sentence row:42966
# id: 6640
# sentence: @handle......no
# -----------------------------------
# Empty sentence row:43128
# id: 9317
# sentence: heartbroken...
# -----------------------------------
# Empty sentence row:43307
# id: 4461
# sentence: @handle jaydyno@handle.com
# -----------------------------------
# Empty sentence row:46612
# id: 2316
# sentence: rt
# -----------------------------------
# Empty sentence row:50589
# id: 8266
# sentence: #ff@handle@handle@handle@handle@handle@handle@handle@handle@handle@handle@handle
# -----------------------------------
# Empty sentence row:50593
# id: 8266
# sentence: *@handle
# -----------------------------------
# Empty sentence row:52039
# id: 5411
# sentence: http://www.ballerstatus.com/2009/11/20/in-rotation-wyclef-jean-akir-stat-quo-ol-dirty-bastard-billy-roadz-slim-the-mobster-more/
# -----------------------------------
# Empty sentence row:52365
# id: 2080
# sentence: http://www.probono.net/ca/news/article.244051-feuer_protecting_lowincome_tenants
# -----------------------------------
# Empty sentence row:52663
# id: 3891
# sentence: @handle
# -----------------------------------
# Empty sentence row:52675
# id: 3891
# sentence: @handle
# -----------------------------------
# Empty sentence row:56315
# id: 9919
# sentence: @handle
# -----------------------------------
# Empty sentence row:61426
# id: 36
# sentence: @handle matt@handle.com
# -----------------------------------
# Empty sentence row:68024
# id: 4505
# sentence: yogurtyogurtyogurtyogurt.
# -----------------------------------
# Empty sentence row:70519
# id: 1281
# sentence: rt@handle
# -----------------------------------
# Empty sentence row:70541
# id: 1281
# sentence: follow@handle
# -----------------------------------
# Empty sentence row:70856
# id: 9440
# sentence: @handle
# -----------------------------------
# Empty sentence row:72685
# id: 1230
# sentence: facebook-twitter???????qt/rt??????????????????(^^;
# -----------------------------------
# Empty sentence row:72708
# id: 1230
# sentence: @handle rt??qt????????????????????????????????????????????????????rom???????????????????????????????????
# -----------------------------------
# Empty sentence row:73631
# id: 2109
# sentence: @handle
# -----------------------------------
# Empty sentence row:78458
# id: 8931
# sentence: @handle. @handle
# -----------------------------------
# Empty sentence row:78641
# id: 6045
# sentence: @handle
# -----------------------------------
# Empty sentence row:82808
# id: 2403
# sentence: @handle hørt!
# -----------------------------------
# Empty sentence row:84205
# id: 4360
# sentence: birthday.
# -----------------------------------
# Empty sentence row:86848
# id: 5061
# sentence: http://www.linkedin.com/in/robertmoore888
# -----------------------------------
# Empty sentence row:92882
# id: 4223
# sentence: http://www.browserforthebetter.com/
# -----------------------------------
# Empty sentence row:93569
# id: 1414
# sentence: rt @handle: #happybirthdaypeter @handle
# -----------------------------------
# Empty sentence row:93783
# id: 7526
# sentence: #4yourentertaiment
# -----------------------------------
# Empty sentence row:93790
# id: 7526
# sentence: #4yourentertainment
# -----------------------------------
# Empty sentence row:95458
# id: 8760
# sentence: @handle jenelle@handle.com
# -----------------------------------
# Empty sentence row:99013
# id: 4935
# sentence: @handle shec@handle.com
# -----------------------------------
# Empty sentence row:100108
# id: 1679
# sentence: @handle
# -----------------------------------
# Empty sentence row:107900
# id: 8153
# sentence: @handle
# -----------------------------------
# Empty sentence row:121134
# id: 2141
# sentence: @handle
# -----------------------------------
# Empty sentence row:123448
# id: 3444
# sentence: ty4rt@handle
# -----------------------------------
# Empty sentence row:124230
# id: 5163
# sentence: @handle dede@handle.net
# -----------------------------------
# Empty sentence row:126836
# id: 6478
# sentence: @handle diamondcityproductions214@handle.com
# -----------------------------------
# Empty sentence row:127117
# id: 6745
# sentence: @handle happybirthday!!!
# -----------------------------------
# Empty sentence row:134332
# id: 2320
# sentence: http://www.entertainmentcareers.net/id/?id=94794
# -----------------------------------
# Empty sentence row:138586
# id: 8094
# sentence: #ff@handle@handle@handle@handle @handle@handle@handle@handle@handle @handle@handle
# -----------------------------------
# Empty sentence row:139454
# id: 7769
# sentence: headhurts
# -----------------------------------
# Empty sentence row:144338
# id: 1319
# sentence: @handle
# -----------------------------------
# Empty sentence row:144751
# id: 9457
# sentence: @handle hot4davedays69@handle.com
# -----------------------------------
# Empty sentence row:149393
# id: 4302
# sentence: @handle
# -----------------------------------
# Empty sentence row:149394
# id: 4302
# sentence: @handle
# -----------------------------------
# Empty sentence row:152880
# id: 286
# sentence: @handle.......sup.??
# -----------------------------------
# Empty sentence row:153328
# id: 9726
# sentence: @handle
# -----------------------------------
# Empty sentence row:156148
# id: 1628
# sentence: @handle oddznendzbeats@handle.com
# -----------------------------------
# Empty sentence row:157760
# id: 3333
# sentence: @handle
# -----------------------------------
# Empty sentence row:158560
# id: 6128
# sentence: @handle http://www.myspace.com/songwritertc
# -----------------------------------
# Empty sentence row:165396
# id: 4208
# sentence: @handle
# -----------------------------------
# Empty sentence row:167213
# id: 2058
# sentence: @handle
# -----------------------------------
# Empty sentence row:167296
# id: 3586
# sentence: @handle
# -----------------------------------
# Empty sentence row:167433
# id: 7394
# sentence: @handle omgrtz
# -----------------------------------
# Empty sentence row:169930
# id: 4389
# sentence: hurts
# -----------------------------------
# Empty sentence row:170034
# id: 5935
# sentence: #followfriday@handle
# -----------------------------------
# Empty sentence row:170446
# id: 6354
# sentence: @handle frank_eliason@handle.com
# -----------------------------------
# Empty sentence row:170574
# id: 3861
# sentence: http://short.to/yj7q
# -----------------------------------
# Empty sentence row:170575
# id: 3861
# sentence: http://short.to/yigg
# -----------------------------------
# Empty sentence row:173090
# id: 4233
# sentence: @handle
# -----------------------------------
# Empty sentence row:173091
# id: 4233
# sentence: @handle
# -----------------------------------
# Empty sentence row:173182
# id: 9614
# sentence: www.myspace.com/prestoentertainment
# -----------------------------------
# Empty sentence row:174079
# id: 2586
# sentence: @handle
# -----------------------------------
# Empty sentence row:174125
# id: 2586
# sentence: @handle
# -----------------------------------
# Empty sentence row:177422
# id: 9844
# sentence: @handle dirty!
# -----------------------------------
# Empty sentence row:179299
# id: 263
# sentence: alefbaybee@handle.com
# -----------------------------------
# Empty sentence row:179565
# id: 1474
# sentence: http://bit.ly/rtcpe
# -----------------------------------
# Empty sentence row:180993
# id: 2662
# sentence: ??[:@handle
# -----------------------------------
# Empty sentence row:182486
# id: 4185
# sentence: @handle
# -----------------------------------
# Empty sentence row:193740
# id: 6501
# sentence: http://cli.gs/gqrta
# -----------------------------------
# Empty sentence row:194199
# id: 2102
# sentence: @handle models@handle.com
# -----------------------------------
# Empty sentence row:196628
# id: 9193
# sentence: @handle
# -----------------------------------
# Empty sentence row:196636
# id: 9193
# sentence: @handle upnextis@handle.com
# -----------------------------------
# Empty sentence row:199886
# id: 5464
# sentence: grrrrrr@handle-mobile
# -----------------------------------
# Empty sentence row:199908
# id: 5464
# sentence: rt@handle
# -----------------------------------
# Empty sentence row:200197
# id: 7890
# sentence: @handle http://www.bnfriends.com/portal
# -----------------------------------
# Empty sentence row:201419
# id: 4524
# sentence: thanks!@handle@handle@handle@handle@handle@handle@handle@handle@handle@handle @handle@handle
# -----------------------------------
# Empty sentence row:201863
# id: 1463
# sentence: @handle dhodgespromotion@handle.com
# -----------------------------------
# Empty sentence row:201864
# id: 1463
# sentence: @handle dhodgespromotion@handle.com
# -----------------------------------
# Empty sentence row:201869
# id: 1463
# sentence: @handle dhodgespromotion@handle.com
# -----------------------------------
# Empty sentence row:203547
# id: 6935
# sentence: @handle...represent!!!!!
# -----------------------------------
# Empty sentence row:205399
# id: 7519
# sentence: @handle tappenfahrt
# -----------------------------------
# Empty sentence row:208494
# id: 5619
# sentence: @handle
# -----------------------------------
# Empty sentence row:214394
# id: 6143
# sentence: http://blogs.telegraph.co.uk/news/jamesdelingpole/100017451/climategate-how-the-msm-reported-the-greatest-scandal-in-modern-science/
# -----------------------------------
# Empty sentence row:215391
# id: 9878
# sentence: rt @handle: @handle <<<diamonds>>>@handle((sparkling))
# -----------------------------------
# Empty sentence row:216807
# id: 4490
# sentence: @handle@
# -----------------------------------
# Empty sentence row:218769
# id: 8320
# sentence: @handle
# -----------------------------------
# Empty sentence row:218779
# id: 8320
# sentence: @handle
# -----------------------------------
# Empty sentence row:221394
# id: 8616
# sentence: http://www.djbooth.net/index/tracks/review/sene-departure-time/
# -----------------------------------
# Empty sentence row:221400
# id: 8616
# sentence: http://www.djbooth.net/index/tracks/review/sene-departure-time/
# -----------------------------------
# Empty sentence row:223728
# id: 6162
# sentence: http://martiansociety.blogspot.com/
# -----------------------------------
# Empty sentence row:225372
# id: 5235
# sentence: @handle *curtsey*
# -----------------------------------
# Empty sentence row:225603
# id: 3484
# sentence: @handle www.eventbrite.com/r/fabfreeadvertise
# -----------------------------------
# Empty sentence row:228318
# id: 3083
# sentence: @handle
# -----------------------------------
# Empty sentence row:229556
# id: 886
# sentence: @handle
# -----------------------------------
# Empty sentence row:231149
# id: 4995
# sentence: @handle thefox3000@handle.com
# -----------------------------------
# Empty sentence row:232403
# id: 6264
# sentence: @handle
# -----------------------------------
# Empty sentence row:234950
# id: 1559
# sentence: @handle escort!
# -----------------------------------
# Empty sentence row:235956
# id: 5135
# sentence: @handle
# -----------------------------------
# Empty sentence row:236287
# id: 8182
# sentence: http://buzz.yahoo.com/article/1:momlogic526:10079afd24615aec2d5d96626d33a8ef/cyber-monday-check-out-the-sales
# -----------------------------------
# Empty sentence row:236544
# id: 2760
# sentence: @handle
# -----------------------------------
# Empty sentence row:237008
# id: 7717
# sentence: @handle start?
# -----------------------------------
# Empty sentence row:240717
# id: 5304
# sentence: @handle
# -----------------------------------
# Empty sentence row:242772
# id: 4636
# sentence: @handle
# -----------------------------------
# Empty sentence row:245201
# id: 4515
# sentence: iliveforthis
# -----------------------------------
# Empty sentence row:248421
# id: 1804
# sentence: @handle
# -----------------------------------
# Empty sentence row:248780
# id: 4712
# sentence: rt @handle,@handle,@handle,@handle,@handle,@handle, @handle,@handle@handle,@handle,@handle
# -----------------------------------
# Empty sentence row:256840
# id: 1859
# sentence: party!
# -----------------------------------
# Empty sentence row:257544
# id: 2685
# sentence: @handle
# -----------------------------------
# Empty sentence row:265284
# id: 1777
# sentence: @handle unearthed
# -----------------------------------
# Empty sentence row:267460
# id: 1776
# sentence: @handle
# -----------------------------------
# Empty sentence row:271053
# id: 3965
# sentence: parttyyyyy
# -----------------------------------
# Empty sentence row:275518
# id: 2070
# sentence: @handle courtney
# -----------------------------------
# Empty sentence row:276718
# id: 6728
# sentence: @handle
# -----------------------------------
# Empty sentence row:281677
# id: 8302
# sentence: sportscenter
# -----------------------------------
# Empty sentence row:283684
# id: 4072
# sentence: f@handle
# -----------------------------------
# Empty sentence row:283686
# id: 4072
# sentence: f@handle
# -----------------------------------
# Empty sentence row:293582
# id: 1094
# sentence: @handle
# -----------------------------------
# Empty sentence row:294189
# id: 6835
# sentence: @handle.rich
# -----------------------------------
# Empty sentence row:294377
# id: 3614
# sentence: @handle
# -----------------------------------
# Empty sentence row:295989
# id: 9845
# sentence: overtime!
# -----------------------------------
# Empty sentence row:300450
# id: 9862
# sentence: @handle
# -----------------------------------
# Empty sentence row:302490
# id: 3954
# sentence: ...@handle.
# -----------------------------------
# Empty sentence row:302980
# id: 9549
# sentence: @handle yes,also-on-astrologyofisis.com,where-u-use-the-self-wheels-which-r-not-2-be-confused-with-the-selfwheels@handleess.com
# -----------------------------------
# Empty sentence row:302982
# id: 9549
# sentence: @handle-remember-looking-at-it,as-it-could-not-be-seen-in-regular-light..thinking,what-have-i-done,as-i-don't-like-tatoos-on-me..lol
# -----------------------------------
# Empty sentence row:304816
# id: 8238
# sentence: @handle
# -----------------------------------
# Empty sentence row:306112
# id: 6131
# sentence: @handle smart
# -----------------------------------
# Empty sentence row:306619
# id: 6050
# sentence: @handle
# -----------------------------------
# Empty sentence row:307958
# id: 5977
# sentence: http://heartlesshandshakes.blogspot.com/2009/09/loudness.html
# -----------------------------------
# Empty sentence row:310365
# id: 1261
# sentence: @handle fourteen
# -----------------------------------
# Empty sentence row:310366
# id: 1261
# sentence: @handle thirteen
# -----------------------------------
# Empty sentence row:310802
# id: 5403
# sentence: http://www1.whdh.com/news/articles/local/bo124867/
# -----------------------------------
# Empty sentence row:310809
# id: 5403
# sentence: http://www1.whdh.com/news/articles/politics/bo124903/
# -----------------------------------
# Empty sentence row:312550
# id: 8410
# sentence: @handle
# -----------------------------------
# Empty sentence row:313654
# id: 7035
# sentence: @handle emilia.nini.giordano@handle.com
# -----------------------------------
# Empty sentence row:313791
# id: 7749
# sentence: homeport
# -----------------------------------
# Empty sentence row:313792
# id: 7749
# sentence: @handle
# -----------------------------------
# Empty sentence row:318124
# id: 8806
# sentence: @handle
# -----------------------------------
# Empty sentence row:319913
# id: 1206
# sentence: http://www.cellulartechnicians.com/facebook/erichatch/fbfpage.htm
# -----------------------------------
# Empty sentence row:328903
# id: 1319
# sentence: @handle
# Total rows: 328931
# Total ids: 9297
# Empty sentence counter: 162
# Time spent: 1848.67ms

# %%
def containSubstr(row, id, sentence, quiet=False):
    #if ("://" in sentence) and ("gn://" not in sentence) and ("http://" not in sentence):
    #if (":/" in sentence):
    #if ("https://" in sentence) and ("http://" in sentence):
    if ("@handle" in sentence):
        if not quiet:
            print("--------------------------------------------")
            print("Row: {0}".format(row+1))
            print("id: {0}".format(id))
            print("Sentence: {0}".format(sentence))
            print("--------------------------------------------")
        return True
    return False

# %%
def extractURL(row, id, sentence, quiet=False):
    target = "http://"
    subStr = sentence
    urlList = []
    while (target in subStr):
        index = subStr.index(target)
        subStr = subStr[index:]
        tempURL = subStr.split()[0]
        subStr = subStr[len(tempURL):]
        tempURL = tempURL[len(target):]
        if len(tempURL) <= 5:
#             print("--------------------------------------------")
#             print("Row: {0}".format(row+1))
#             print("Sentence: {0}".format(sentence))
#             print(tempURL)
            continue
        if "http://" in tempURL:
            newURLList = tempURL.split("http://")
            if '' in newURLList:
                newURLList.remove('')
            for newURLListItem in newURLList:
                if '/' in newURLListItem:
                    newURLListItem = newURLListItem.split('/')[0]
                    part = newURLListItem.split('.')
                    urlList.append("{0}.{1}".format(part[-2], part[-1]))
            continue
        elif "http:/" in tempURL:
            tempURL = tempURL.replace("http:/", '')
            if len(tempURL) < 5:
                continue
        if '/' in tempURL:
            tempURL = tempURL.split('/')[0]
        part = tempURL.split('.')
        while '' in part:
            part.remove('')
        if len(part) < 2:
            continue
        tempURL = "{0}.{1}".format(part[-2], part[-1])
        if '?' in tempURL:
            part = tempURL.split("?")
            while '' in part:
                part.remove('')
            tempURL = part[0]
        urlList.append(tempURL)
    if (0 != len(urlList)) and (not quiet):
        print("--------------------------------------------")
        print("Row: {0}".format(row+1))
        print("id: {0}".format(id))
        print("Sentence: {0}".format(sentence))
        print("--------------------------------------------")
    return urlList

# %%
counter = 0
userMap = {}
urlMap = {}
with open(train_file_path, encoding='utf-8') as tsvfile:
    lines = tsvfile.readlines()
    for i, row in enumerate(lines):
        row = row.strip().split("\t")
        id = int(row[0])
        instance = row[1].lower()
#         if containSubstr(i, id, instance, quiet=True):
#         if containSubstr(i, id, instance, quiet=True):
#            if id in userMap.keys():
#                userMap[id] += 1
#            else:
#                userMap[id] = 1
        urlList = extractURL(i, id, instance, quiet=True)
        len_urlList = len(urlList)
        if (0 != len_urlList):
            if id in userMap.keys():
                userMap[id] += len_urlList
            else:
                userMap[id] = len_urlList
            if id in urlMap.keys():
                urlMap[id] += urlList
            else:
                urlMap[id] = urlList
        counter += 1

# %%
counterMap = {}
for key in userMap.keys():
    tempNum = userMap[key]
    if tempNum in counterMap.keys():
        counterMap[tempNum].append(key)
    else:
        counterMap[tempNum] = [key]

x = list(counterMap.keys()).copy()
x.sort()
x = x[50:]
y = []
for key in x:
    y.append(len(counterMap[key]))

# %matplotlib inline
plt.plot(x, y)
plt.xlabel("Tweets contains key words pre user")
plt.ylabel("num of users")
plt.show()
print("tweets: %d, users len: %d" % (counter, len(userMap.keys())))
#print(counterMap.keys())
#print(sum(y[:20]))

# %%
def sortedDictValues(adict): 
    keys = list(adict.keys())
    keys.sort()
    return [(key, adict[key]) for key in keys]

urlUserMap = {}
for user in urlMap.keys():
    for url in urlMap[user]:
        if url in urlUserMap.keys():
            urlUser = urlUserMap[url]
            if user in urlUser.keys():
                urlUser[user] += 1
            else:
                urlUser[user] = 1
        else:
            urlUserMap[url] = {user : 1}

# sort user
for urlUser in urlUserMap.keys():
    urlUserMap[urlUser] = sortedDictValues(urlUserMap[urlUser])

urlUserListSorted = sortedDictValues(urlUserMap)
# output sorted url
with open("data/sortedURL.csv", 'w') as file:
    for (url, item) in urlUserListSorted:
        for (user, frequency) in item:
            file.write("{0},{1},{2}\n".format(url,user,frequency))
