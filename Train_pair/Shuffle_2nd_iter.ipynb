# %%
import pandas as pd


second_pair_data = pd.read_csv('./new_split_pair_all.txt', sep='\t', header=None)

# %%
second_pair_data
# Out:
#                                                          0  \
# 0        Technology Review counted 967,000 monthly uniq...
# 1        Technology Review counted 967,000 monthly uniq...
# 2        Technology Review counted 967,000 monthly uniq...
# 3        Technology Review counted 967,000 monthly uniq...
# 4        Technology Review counted 967,000 monthly uniq...
# 5        Technology Review counted 967,000 monthly uniq...
# 6        Technology Review counted 967,000 monthly uniq...
# 7        Technology Review counted 967,000 monthly uniq...
# 8        Technology Review counted 967,000 monthly uniq...
# 9        Technology Review counted 967,000 monthly uniq...
# 10       Technology Review counted 967,000 monthly uniq...
# 11       Technology Review counted 967,000 monthly uniq...
# 12       Technology Review counted 967,000 monthly uniq...
# 13       Technology Review counted 967,000 monthly uniq...
# 14       Technology Review counted 967,000 monthly uniq...
# ...

# %%
import numpy as np

np.mean(np.array(second_pair_data[2]))
# Out:
# 0.2989623317815951

# %%
from sklearn.utils import shuffle

shuffled = shuffle(second_pair_data)

# %%
shuffled
# Out:
#                                                          0  \
# 1990150  Gaping hole, broken water main slow beach driv...
# 102169   Obama: I’m Too Clumsy for Twitter: Speaking to...
# 266508         What state has the best football prospects?
# 972236   Bankruptcy and Amends - SoberRecovery : Alcoho...
# 1034849  To Use or Not To Use Forex Signals: By Tim Kal...
# 1713520  Good morning and happy Thanksgiving! Coffee br...
# 818767          Permission Marketing | Seth Godin bte #RTW
# 301372   this Saturday at the Hkan on Carson Street Jug...
# 36352    Blue green alge contains a photonutrent involv...
# 799367   you're much faster than I... I'm like the tort...
# 1685765  Microsoft extends Windows 7 and Azure to open ...
# 2175789  Kristen Stewart On The Tonight Show With Conan...
# 1221001  Halloween Ideas - Spider Web Throw Rug | Bukis...
# 612508   Gang accused of killing to sell human fat (sou...
# 542413   Limited supply offer on $5.95/mo VPS servers f...
# ...

# %%
shuffled.to_csv('./second_iter_train.csv', header=None, index=False, sep='\t')
